# %%
2+2
# Out:
# 4

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(-100,25,100)

# %%
y=x**2

# %%
plt.plot(x,y)
plt.show()

# %%
y=(x**3)+7*x

# %%
plt.plot(x,y)
plt.show()

# %%
y=np.cos(x)

# %%
plt.plot(x,y)
plt.show()

# %%
y=np.cosh(x)

# %%
plt.plot(x,y)
plt.show()

# %%
y=np.sin(x)*np.exp(-0.1*x)

# %%
plt.plot(x,y)
plt.show()
